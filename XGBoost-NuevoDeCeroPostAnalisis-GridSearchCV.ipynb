# %%
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from numpy import sort
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
#DataSet Limpio con columnas no utiles segun analisis droppeadas.

oportunidades = pd.read_csv("Train_TP2_Datos_2020-2C.csv")
oportunidades['Account_Created_Date'] = pd.to_datetime(oportunidades['Account_Created_Date'])
oportunidades['Opportunity_Created_Date'] = pd.to_datetime(oportunidades['Opportunity_Created_Date'])
oportunidades['Quote_Expiry_Date'] = pd.to_datetime(oportunidades['Quote_Expiry_Date'])
oportunidades['Last_Modified_Date'] = pd.to_datetime(oportunidades['Last_Modified_Date'])
oportunidades['Planned_Delivery_Start_Date'] = pd.to_datetime(oportunidades['Planned_Delivery_Start_Date'])
oportunidades['Planned_Delivery_End_Date'] = pd.to_datetime(oportunidades['Planned_Delivery_End_Date'])
oportunidades_japon = (oportunidades.loc[oportunidades['Region'] == 'Japan'])
oportunidades = (oportunidades.loc[oportunidades['Region'] != 'Japan'])
#oportunidades_japon = oportunidades_japon.iloc[:,:3]
oportunidades_japon['Territory'] = oportunidades_japon['Territory'].replace({'None':'Japan'})
oportunidades = pd.concat([oportunidades, oportunidades_japon], axis=0)
oportunidades['Region'] = oportunidades['Region'].replace({'Japan':'APAC', 'Middle East':'EMEA'})
oportunidades[oportunidades.select_dtypes(['object']).columns] = oportunidades.select_dtypes(['object']).apply(lambda x: x.astype('category'))
oportunidades = oportunidades.loc[oportunidades['Territory'] != 'None']
oportunidades['Conversion_Moneda'] = oportunidades['ASP'] / oportunidades['ASP_(converted)']
oportunidades['Total_Amount'] = oportunidades['Total_Amount'] / oportunidades['Conversion_Moneda']
oportunidades['Total_Taxable_Amount'] = oportunidades['Total_Taxable_Amount'] / oportunidades['Conversion_Moneda']
oportunidades = oportunidades[(oportunidades['Stage'] == 'Closed Won') | (oportunidades['Stage'] == 'Closed Lost')]
oportunidades['Stage'] = oportunidades['Stage'].replace({'Closed Won':1, 'Closed Lost':0})
oportunidades = oportunidades.drop(['Pricing, Delivery_Terms_Quote_Appr'\
    ,'Pricing, Delivery_Terms_Approved', 'Bureaucratic_Code_0_Approval'\
        , 'Bureaucratic_Code_0_Approved','Submitted_for_Approval', \
    'Billing_Country','Account_Created_Date', 'Opportunity_Name','Delivery_Year',\
   'Actual_Delivery_Date','Prod_Category_A','Product_Category_B','Delivery_Quarter','Month',\
   'Planned_Delivery_End_Date','Planned_Delivery_Start_Date','ASP_(converted)_Currency','ASP_Currency',\
   'ASP','ASP_(converted)', 'Sales_Contract_No', 'Bureaucratic_Code', 'Opportunity_Created_Date', 'Brand',\
   'Product_Type','Size','Price','Currency','Last_Activity','Quote_Expiry_Date','Last_Modified_Date','Last_Modified_By','ID',\
   'Delivery_Terms','Conversion_Moneda', 'Total_Taxable_Amount_Currency', 'Quote_Type'], axis = 'columns')
oportunidades = oportunidades.dropna()
oportunidades
# Out:
#          Region   Territory    Source        Account_Name  Opportunity_ID  \
# 2      Americas  NW America   Source_7  Account_Name_1794               2
# 3      Americas  NW America  Source_11  Account_Name_1201               3
# 4      Americas  NW America  Source_11  Account_Name_1201               4
# 5      Americas  NW America  Source_11  Account_Name_1201               5
# 6      Americas  NW America  Source_11  Account_Name_1201               6
# ...         ...         ...        ...                ...             ...
# 16922      APAC       Japan   Source_7  Account_Name_1294           12785
# 16923      APAC       Japan   Source_3  Account_Name_1074           12786
# 16924      APAC       Japan   Source_3  Account_Name_1074           12787
# 16925      APAC       Japan  Source_11  Account_Name_1522           12788
# 16926      APAC       Japan  Source_11  Account_Name_1522           12789
#
#         Account_Owner Opportunity_Owner    Account_Type     Opportunity_Type  \
# 2      Person_Name_64     Person_Name_8  Account_Type_5   Opportunity_Type_1
# 3       Person_Name_8     Person_Name_8  Account_Type_5  Opportunity_Type_19
# 4       Person_Name_8     Person_Name_8  Account_Type_5  Opportunity_Type_19
# 5       Person_Name_8     Person_Name_8  Account_Type_5  Opportunity_Type_19
# 6       Person_Name_8     Person_Name_8  Account_Type_5  Opportunity_Type_19
# ...               ...               ...             ...                  ...
# 16922  Person_Name_66    Person_Name_66  Account_Type_2   Opportunity_Type_1
# 16923  Person_Name_61    Person_Name_66  Account_Type_0   Opportunity_Type_1
# 16924  Person_Name_61    Person_Name_66  Account_Type_0   Opportunity_Type_1
# 16925  Person_Name_50    Person_Name_30  Account_Type_0  Opportunity_Type_10
# 16926  Person_Name_50    Person_Name_30  Account_Type_0  Opportunity_Type_10
#
#            Product_Family      Product_Name  TRF Total_Amount_Currency  \
# 2       Product_Family_81   Product_Name_91    0                   USD
# 3      Product_Family_209  Product_Name_432   14                   USD
# 4      Product_Family_209  Product_Name_432   25                   USD
# 5      Product_Family_209  Product_Name_432   28                   USD
# 6      Product_Family_164  Product_Name_308    7                   USD
# ...                   ...               ...  ...                   ...
# 16922  Product_Family_243  Product_Name_508    0                   USD
# 16923   Product_Family_77  Product_Name_100    0                   JPY
# 16924   Product_Family_73   Product_Name_85    0                   JPY
# 16925   Product_Family_77  Product_Name_100    0                   JPY
# 16926  Product_Family_111  Product_Name_153    0                   JPY
#
#        Total_Amount  Total_Taxable_Amount  Stage
# 2      8.386560e+04          8.386560e+04      1
# 3      7.421882e+06          7.421882e+06      0
# 4      1.335719e+07          1.335719e+07      0
# 5      1.483828e+07          1.483828e+07      0
# 6      2.659495e+06          2.659495e+06      0
# ...             ...                   ...    ...
# 16922  1.320000e+04          6.422401e+06      1
# 16923  1.096295e+05          1.096295e+05      1
# 16924  1.075213e+05          1.075213e+05      1
# 16925  1.576650e+05          1.576650e+05      1
# 16926  1.246072e+05          1.246072e+05      1
#
# [12642 rows x 16 columns]

# %%
# Encodeos necesarios:
#----------------------------------------------------------------------------------------------------
# Total_Amount_Currency(AUD y JPY)
# Region (APAC)
# Territorio (Mean Stage)
# Dif_Amount(TAm-TTAm)
# TRF > 0
# Product_Family(En base a ranking o mean de Stage)
# Product_Name(En base a ranking o mean de Stage)
# Total Amount y Total Tax hay que dropearlos despues del Dif_Amount
# Account Name (Ranking o Mean Stage)
# Opportunity Owner (Ranking o Mean Stage)
# Account Owner (Ranking o Mean Stage)
# Account Type (Ranking o Mean Stage)
# Opportunity Type (Ranking o Mean Stage)
# Source (Decidir el encodeo)
#---------------------------------------------------------------------------------------------------

# %%
# Total_Amount_Currency(AUD y JPY)
# Region (APAC)

oportunidades['Currency_Es_JPY_O_AUD'] = ((oportunidades['Total_Amount_Currency'] == 'AUD') | \
                                  (oportunidades['Total_Amount_Currency'] == 'JPY')).replace({True:1,False:0})
oportunidades['Region_Es_APAC'] = (oportunidades['Region'] == 'APAC').replace({True:1,False:0})
oportunidades = oportunidades.drop(columns=['Region','Total_Amount_Currency'])

# %%
# Territorio (Mean Stage)

gby_terr = oportunidades.groupby('Territory').agg({'Stage':'mean'})
gby_terr['Stage'] = gby_terr['Stage'].replace({np.nan:(gby_terr['Stage'].mean())})
terrs_sorted = gby_terr.sort_values(by='Stage')
terrs_sorted = terrs_sorted.reset_index()
terrs_sorted.columns = ['Territory', 'Encoding_Territory']
oportunidades = oportunidades.merge(terrs_sorted, on='Territory')
oportunidades = oportunidades.drop(columns=['Territory'])

# %%
# Dif_Amount(TAm-TTAm)

amounts = oportunidades.groupby('Opportunity_ID').agg({'Total_Amount':'sum','Total_Taxable_Amount':'mean'})
amounts['Diferencia_Amounts'] = amounts['Total_Amount']-amounts['Total_Taxable_Amount']
amounts = amounts.drop(columns = ['Total_Amount','Total_Taxable_Amount'])
amounts = amounts.reset_index()
oportunidades = oportunidades.merge(amounts, on='Opportunity_ID')
oportunidades = oportunidades.drop(columns = ['Total_Amount','Total_Taxable_Amount'])

# %%
# TRF > 0

trf = oportunidades.groupby('Opportunity_ID').agg({'TRF':'sum'})
trf['TRF_Mayor_A_0'] = trf['TRF']>0
trf = trf.drop(columns=['TRF'])
trf = trf.reset_index()
oportunidades = oportunidades.merge(trf, on='Opportunity_ID')
oportunidades = oportunidades.drop(columns=['TRF'])
oportunidades['TRF_Mayor_A_0'] = oportunidades['TRF_Mayor_A_0'].replace({True:1,False:0})

# %%
# Product_Family(Mean Stage)

gby_prod_fam = oportunidades.groupby('Product_Family').agg({'Stage':'mean'})
gby_prod_fam['Stage'] = gby_prod_fam['Stage'].replace({np.nan:(gby_prod_fam['Stage'].mean())})
p_fam_sorted = gby_prod_fam.sort_values(by='Stage')
p_fam_sorted = p_fam_sorted.reset_index()
p_fam_sorted.columns = ['Product_Family', 'Encoding_Prod_Family']
oportunidades = oportunidades.merge(p_fam_sorted, on='Product_Family')
oportunidades = oportunidades.drop(columns=['Product_Family'])

# %%
# Product_Name(En base a ranking)

gby_prod_name = oportunidades.groupby('Product_Name').agg({'Stage':'mean'})
gby_prod_name['Stage'] = gby_prod_name['Stage'].replace({np.nan:(gby_prod_name['Stage'].mean())})
p_name_sorted = gby_prod_name.sort_values(by='Stage')
p_name_sorted = p_name_sorted.reset_index()
p_name_sorted = p_name_sorted.reset_index()
p_name_sorted = p_name_sorted.drop(columns=['Stage'])
p_name_sorted.columns = ['Encoding_Prod_Name', 'Product_Name']
oportunidades = oportunidades.merge(p_name_sorted, on='Product_Name')
oportunidades = oportunidades.drop(columns=['Product_Name'])

# %%
# Account Name (Mean Stage)
gby_acc_name = oportunidades.groupby('Account_Name').agg({'Stage':'mean'})
gby_acc_name['Stage'] = gby_acc_name['Stage'].replace({np.nan:(gby_acc_name['Stage'].mean())})
acc_name_sorted = gby_acc_name.sort_values(by='Stage')
acc_name_sorted = acc_name_sorted.reset_index()
acc_name_sorted.columns = ['Account_Name', 'Encoding_Account_Name']
oportunidades = oportunidades.merge(acc_name_sorted, on='Account_Name')
oportunidades = oportunidades.drop(columns=['Account_Name'])

# %%
# Opportunity Owner (Ranking)

gby_op_ow = oportunidades.groupby('Opportunity_Owner').agg({'Stage':'mean'})
gby_op_ow['Stage'] = gby_op_ow['Stage'].replace({np.nan:(gby_op_ow['Stage'].mean())})
op_ow_sorted = gby_op_ow.sort_values(by='Stage')
op_ow_sorted = op_ow_sorted.reset_index()
op_ow_sorted = op_ow_sorted.reset_index()
op_ow_sorted = op_ow_sorted.drop(columns=['Stage'])
op_ow_sorted.columns = ['Encoding_Opportunity_Owner', 'Opportunity_Owner']
oportunidades = oportunidades.merge(op_ow_sorted, on='Opportunity_Owner')
oportunidades = oportunidades.drop(columns=['Opportunity_Owner'])

# %%
# Account Owner (Mean Stage)

gby_acc_ow = oportunidades.groupby('Account_Owner').agg({'Stage':'mean'})
gby_acc_ow['Stage'] = gby_acc_ow['Stage'].replace({np.nan:(gby_acc_ow['Stage'].mean())})
acc_ow_sorted = gby_acc_ow.sort_values(by='Stage')
acc_ow_sorted = acc_ow_sorted.reset_index()
acc_ow_sorted.columns = ['Account_Owner', 'Encoding_Account_Owner']
oportunidades = oportunidades.merge(acc_ow_sorted, on='Account_Owner')
oportunidades = oportunidades.drop(columns=['Account_Owner'])

# %%
# Account Type (Ranking)

gby_acc_type = oportunidades.groupby('Account_Type').agg({'Stage':'mean'})
gby_acc_type['Stage'] = gby_acc_type['Stage'].replace({np.nan:(gby_acc_type['Stage'].mean())})
acc_type_sorted = gby_acc_type.sort_values(by='Stage')
acc_type_sorted = acc_type_sorted.reset_index()
acc_type_sorted = acc_type_sorted.reset_index()
acc_type_sorted = acc_type_sorted.drop(columns=['Stage'])
acc_type_sorted.columns = ['Encoding_Account_Type', 'Account_Type']
oportunidades = oportunidades.merge(acc_type_sorted, on='Account_Type')
oportunidades = oportunidades.drop(columns=['Account_Type'])

# %%
# Opportunity Type (Mean Stage)

gby_op_type = oportunidades.groupby('Opportunity_Type').agg({'Stage':'mean'})
gby_op_type['Stage'] = gby_op_type['Stage'].replace({np.nan:(gby_op_type['Stage'].mean())})
op_type_sorted = gby_op_type.sort_values(by='Stage')
op_type_sorted = op_type_sorted.reset_index()
op_type_sorted.columns = ['Opportunity_Type', 'Encoding_Opportunity_Type']
oportunidades = oportunidades.merge(op_type_sorted, on='Opportunity_Type')
oportunidades = oportunidades.drop(columns=['Opportunity_Type'])

# %%
# Source (Decidir el encodeo)

# %%
oportunidades
# Out:
#         Source   Opportunity_ID  Stage  Currency_Es_JPY_O_AUD  Region_Es_APAC  \
# 0      Source_7               2      1                      0               0
# 1      Source_7            1315      1                      0               0
# 2      Source_7            1316      1                      0               0
# 3      Source_7            2889      1                      0               0
# 4      Source_7               7      1                      0               0
# ...         ...             ...    ...                    ...             ...
# 12637      None            3517      0                      0               1
# 12638      None            3518      0                      0               1
# 12639  Source_7            2782      1                      0               1
# 12640  Source_7            2783      1                      0               1
# 12641  Source_7            2883      1                      0               1
#
#        Encoding_Territory  Diferencia_Amounts  TRF_Mayor_A_0  \
# 0                0.631246                 0.0              0
# 1                0.631246                 0.0              0
# 2                0.631246                 0.0              0
# 3                0.631246                 0.0              0
# 4                0.631246                 0.0              0
# ...                   ...                 ...            ...
# 12637            0.272727                 0.0              1
# 12638            0.272727                 0.0              1
# 12639            0.684917                 0.0              1
# 12640            0.684917                 0.0              1
# 12641            0.684917                 0.0              1
#
#        Encoding_Prod_Family  Encoding_Prod_Name  Encoding_Account_Name  \
# 0                  0.833333                 379               0.826667
# 1                  0.325779                 301               0.826667
# 2                  0.325779                 301               0.826667
# 3                  0.325779                 301               0.826667
# 4                  0.636364                 327               0.826667
# ...                     ...                 ...                    ...
# 12637              0.612613                 147               0.125000
# 12638              0.612613                 147               0.125000
# 12639              0.818182                 388               0.882353
# 12640              0.818182                 388               0.882353
# 12641              0.818182                 388               0.882353
#
#        Encoding_Opportunity_Owner  Encoding_Account_Owner  \
# 0                              39                0.675481
# 1                              39                0.675481
# 2                              39                0.675481
# 3                              39                0.675481
# 4                              39                0.675481
# ...                           ...                     ...
# 12637                          14                0.807074
# 12638                          14                0.807074
# 12639                          52                0.700980
# 12640                          52                0.700980
# 12641                          52                0.700980
#
#        Encoding_Account_Type  Encoding_Opportunity_Type
# 0                          3                   0.545089
# 1                          3                   0.545089
# 2                          3                   0.545089
# 3                          3                   0.545089
# 4                          3                   0.545089
# ...                      ...                        ...
# 12637                      5                   0.333333
# 12638                      5                   0.333333
# 12639                      5                   0.333333
# 12640                      5                   0.333333
# 12641                      5                   0.333333
#
# [12642 rows x 15 columns]

# %%
x_train = oportunidades.groupby('Opportunity_ID').agg({'Currency_Es_JPY_O_AUD':'mean', 'Region_Es_APAC':'mean',\
                                 'Encoding_Territory':'mean', 'Diferencia_Amounts':'mean', 'TRF_Mayor_A_0':'mean',\
                                 'Encoding_Prod_Family':'mean','Encoding_Prod_Name':'mean','Encoding_Account_Name':'mean',\
                                 'Encoding_Opportunity_Owner':'mean','Encoding_Account_Owner':'mean','Encoding_Account_Type':'mean',\
                                  'Encoding_Opportunity_Type':'mean'})
y_train = oportunidades.groupby('Opportunity_ID').agg({'Stage':'max'})
division_x_train, division_x_test, division_y_train, division_y_test = train_test_split(x_train, y_train, test_size = 0.3,\
                                                                                       random_state = 123)
x_train
# Out:
#                 Currency_Es_JPY_O_AUD  Region_Es_APAC  Encoding_Territory  \
# Opportunity_ID
# 2                                   0               0            0.631246
# 3                                   0               0            0.631246
# 4                                   0               0            0.631246
# 5                                   0               0            0.631246
# 6                                   0               0            0.631246
# ...                               ...             ...                 ...
# 12799                               0               0            0.421053
# 12800                               0               0            0.335252
# 12801                               0               0            0.855172
# 12802                               0               0            0.335252
# 12803                               0               0            0.335252
#
#                 Diferencia_Amounts  TRF_Mayor_A_0  Encoding_Prod_Family  \
# Opportunity_ID
# 2                             0.00              0              0.833333
# 3                             0.00              1              0.243767
# 4                             0.00              1              0.243767
# 5                             0.00              1              0.243767
# 6                             0.00              1              0.325779
# ...                            ...            ...                   ...
# 12799                         0.00              1              0.502816
# 12800                         0.00              1              0.318974
# 12801                         0.00              0              0.579137
# 12802                   2346796.88              1              0.312169
# 12803                  25603200.00              1              0.325779
#
#                 Encoding_Prod_Name  Encoding_Account_Name  \
# Opportunity_ID
# 2                            379.0               0.826667
# 3                             99.0               0.000000
# 4                             99.0               0.000000
# 5                             99.0               0.000000
# 6                            127.0               0.000000
# ...                            ...                    ...
# 12799                        186.0               0.670213
# 12800                        122.5               0.000000
# 12801                        341.0               1.000000
# 12802                        153.0               0.000000
# 12803                        104.0               0.000000
#
#                 Encoding_Opportunity_Owner  Encoding_Account_Owner  \
# Opportunity_ID
# 2                                       39                0.675481
# 3                                       39                0.594979
# 4                                       39                0.594979
# 5                                       39                0.594979
# 6                                       39                0.594979
# ...                                    ...                     ...
# 12799                                   43                0.672492
# 12800                                   43                0.672492
# 12801                                   43                0.672492
# 12802                                   17                0.278322
# 12803                                   17                0.278322
#
#                 Encoding_Account_Type  Encoding_Opportunity_Type
# Opportunity_ID
# 2                                   3                   0.545089
# 3                                   3                   0.222024
# 4                                   3                   0.222024
# 5                                   3                   0.222024
# 6                                   3                   0.222024
# ...                               ...                        ...
# 12799                               6                   0.545089
# 12800                               3                   0.222024
# 12801                               3                   0.545089
# 12802                               3                   0.545089
# 12803                               3                   0.222024
#
# [9029 rows x 12 columns]

# %%
model = GridSearchCV(xgb.XGBRegressor(objective ='binary:logistic', n_estimators = 450, eval_metric='logloss'), {
    'learning_rate' : np.arange(0.008, 0.022, 0.004),
    'colsample_bytree' : np.arange(0.4,0.9,0.1),
    'alpha' : [0.0001,0.001,0.01,0.1],
    'max_depth' : np.arange(4,10),
    'gamma' : np.arange(0,0.3,0.05),
    'subsample' : np.arange(0.5,1,0.1)
}, cv = 2, return_train_score = False, n_jobs = -1, verbose=10,scoring=neg_log_loss)

model.fit(division_x_train, division_y_train)
# Out:
# Fitting 2 folds for each of 14400 candidates, totalling 28800 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   36.9s
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 521 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 554 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 589 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 661 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 698 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 737 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 817 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 858 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 901 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 944 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 1034 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 1081 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 1128 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 1177 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 1226 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 1277 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 1328 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 1381 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 1489 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 1544 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 1601 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 1658 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 1717 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 1776 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 1837 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 1898 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 2024 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 2089 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 2154 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 2221 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 2357 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 2426 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 2497 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 2568 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 2641 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 2714 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 2789 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 2864 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 2941 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 3018 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 3097 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 3176 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 3257 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 3338 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 3421 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 3504 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 3589 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 3674 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 3761 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 3848 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 3937 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 4026 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done 4117 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 4208 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 4301 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 4394 tasks      | elapsed: 20.1min
# [Parallel(n_jobs
# [Parallel(n_jobs=-1)]: Done 15464 tasks      | elapsed: 70.8min
# [Parallel(n_jobs=-1)]: Done 15641 tasks      | elapsed: 71.5min
# [Parallel(n_jobs=-1)]: Done 15818 tasks      | elapsed: 72.2min
# [Parallel(n_jobs=-1)]: Done 15997 tasks      | elapsed: 73.0min
# [Parallel(n_jobs=-1)]: Done 16176 tasks      | elapsed: 73.8min
# [Parallel(n_jobs=-1)]: Done 16357 tasks      | elapsed: 74.6min
# [Parallel(n_jobs=-1)]: Done 16538 tasks      | elapsed: 75.4min
# [Parallel(n_jobs=-1)]: Done 16721 tasks      | elapsed: 76.2min
# [Parallel(n_jobs=-1)]: Done 16904 tasks      | elapsed: 77.0min
# [Parallel(n_jobs=-1)]: Done 17089 tasks      | elapsed: 77.8min
# [Parallel(n_jobs=-1)]: Done 17274 tasks      | elapsed: 78.6min
# [Parallel(n_jobs=-1)]: Done 17461 tasks      | elapsed: 79.5min
# [Parallel(n_jobs=-1)]: Done 17648 tasks      | elapsed: 80.3min
# [Parallel(n_jobs=-1)]: Done 17837 tasks      | elapsed: 81.2min
# [Parallel(n_jobs=-1)]: Done 18026 tasks      | elapsed: 82.0min
# [Parallel(n_jobs=-1)]: Done 18217 tasks      | elapsed: 82.9min
# [Parallel(n_jobs=-1)]: Done 18408 tasks      | elapsed: 83.7min
# [Parallel(n_jobs=-1)]: Done 18601 tasks      | elapsed: 84.6min
# [Parallel(n_jobs=-1)]: Done 18794 tasks      | elapsed: 85.5min
# [Parallel(n_jobs=-1)]: Done 18989 tasks      | elapsed: 86.4min
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed: 87.3min
# [Parallel(n_jobs=-1)]: Done 19381 tasks      | elapsed: 88.2min
# [Parallel(n_jobs=-1)]: Done 19578 tasks      | elapsed: 89.1min
# [Parallel(n_jobs=-1)]: Done 19777 tasks      | elapsed: 90.1min
# [Parallel(n_jobs=-1)]: Done 19976 tasks      | elapsed: 91.1min
# [Parallel(n_jobs=-1)]: Done 20177 tasks      | elapsed: 92.0min
# [Parallel(n_jobs=-1)]: Done 20378 tasks      | elapsed: 93.0min
# [Parallel(n_jobs=-1)]: Done 20581 tasks      | elapsed: 94.0min
# [Parallel(n_jobs=-1)]: Done 20784 tasks      | elapsed: 95.0min
# [Parallel(n_jobs=-1)]: Done 20989 tasks      | elapsed: 96.0min
# [Parallel(n_jobs=-1)]: Done 21194 tasks      | elapsed: 97.0min
# [Parallel(n_jobs=-1)]: Done 21401 tasks      | elapsed: 98.0min
# [Parallel(n_jobs=-1)]: Done 21608 tasks      | elapsed: 99.0min
# [Parallel(n_jobs=-1)]: Done 21817 tasks      | elapsed: 99.8min
# [Parallel(n_jobs=-1)]: Done 22026 tasks      | elapsed: 100.6min
# [Parallel(n_jobs=-1)]: Done 22237 tasks      | elapsed: 101.5min
# [Parallel(n_jobs=-1)]: Done 22448 tasks      | elapsed: 102.3min
# [Parallel(n_jobs=-1)]: Done 22661 tasks      | elapsed: 103.2min
# [Parallel(n_jobs=-1)]: Done 22874 tasks      | elapsed: 104.0min
# [Parallel(n_jobs=-1)]: Done 23089 tasks      | elapsed: 104.9min
# [Parallel(n_jobs=-1)]: Done 23304 tasks      | elapsed: 105.8min
# [Parallel(n_jobs=-1)]: Done 23521 tasks      | elapsed: 106.8min
# [Parallel(n_jobs=-1)]: Done 23738 tasks      | elapsed: 107.7min
# [Parallel(n_jobs=-1)]: Done 23957 tasks      | elapsed: 108.7min
# [Parallel(n_jobs=-1)]: Done 24176 tasks      | elapsed: 109.7min
# [Parallel(n_jobs=-1)]: Done 24397 tasks      | elapsed: 110.6min
# [Parallel(n_jobs=-1)]: Done 24618 tasks      | elapsed: 111.6min
# [Parallel(n_jobs=-1)]: Done 24841 tasks      | elapsed: 112.7min
# [Parallel(n_jobs=-1)]: Done 25064 tasks      | elapsed: 113.7min
# [Parallel(n_jobs=-1)]: Done 25289 tasks      | elapsed: 114.7min
# [Parallel(n_jobs=-1)]: Done 25514 tasks      | elapsed: 115.7min
# [Parallel(n_jobs=-1)]: Done 25741 tasks      | elapsed: 116.7min
# [Parallel(n_jobs=-1)]: Done 25968 tasks      | elapsed: 117.8min
# [Parallel(n_jobs=-1)]: Done 26197 tasks      | elapsed: 118.8min
# [Parallel(n_jobs=-1)]: Done 26426 tasks      | elapsed: 119.9min
# [Parallel(n_jobs=-1)]: Done 26657 tasks      | elapsed: 121.0min
# [Parallel(n_jobs=-1)]: Done 26888 tasks      | elapsed: 122.1min
# [Parallel(n_jobs=-1)]: Done 27121 tasks      | elapsed: 123.2min
# [Parallel(n_jobs=-1)]: Done 27354 tasks      | elapsed: 124.3min
# [Parallel(n_jobs=-1)]: Done 27589 tasks      | elapsed: 125.4min
# [Parallel(n_jobs=-1)]: Done 27824 tasks      | elapsed: 126.6min
# [Parallel(n_jobs=-1)]: Done 28061 tasks      | elapsed: 127.7min
# [Parallel(n_jobs=-1)]: Done 28298 tasks      | elapsed: 128.9min
# [Parallel(n_jobs=-1)]: Done 28537 tasks      | elapsed: 130.0min
# [Parallel(n_jobs=-1)]: Done 28776 tasks      | elapsed: 131.2min
# [Parallel(n_jobs=-1)]: Done 28800 out of 28800 | elapsed: 131.3min finished
# GridSearchCV(cv=2,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     eval_metric='logloss', gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_...
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              n_jobs=-1,
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1],
#                          'colsample_bytree': array([0.4, 0.5, 0.6, 0.7, 0.8]),
#                          'gamma': array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25]),
#                          'learning_rate': array([0.008, 0.012, 0.016, 0.02 ]),
#                          'max_depth': array([4, 5, 6, 7, 8, 9]),
#                          'subsample': array([0.5, 0.6, 0.7, 0.8, 0.9])},
#              verbose=10)

# %%
accuracy_score(division_y_test, model.predict(division_x_test).round())
# Out:
# 0.8313030638612035

# %%
log_loss(division_y_test, model.predict(division_x_test))
# Out:
# 0.3577076656708839

# %%
model.best_params_
# Out:
# {'alpha': 0.1,
#  'colsample_bytree': 0.5,
#  'gamma': 0.1,
#  'learning_rate': 0.02,
#  'max_depth': 6,
#  'subsample': 0.8999999999999999}
